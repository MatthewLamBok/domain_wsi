# %%
# %cd /home/mlam/Documents/Research_Project/WSI_domain/WSI-domain-specific/

# %%
# !ls
# Out:
# Checkpoint_p2.py	    heatmap_utils.py  smooth-topk
# create_heatmaps.sh	    LICENSE	      test_information_part_2.py
# create_patches_features.sh  lightning_logs    test_information.py
# CustomOptim		    models	      train_seeded_cross.py
# dataset.py		    netcal_lib	      train_seeded.py
# eval.py			    __pycache__       utils.py
# eval_utils.py		    README.md	      VOIDCheckpoint_p3.py
# feature_dataset.py	    requirements.txt  writer.py
# feature_extraction.py	    runs	      wsi_core
# heatmaps.py		    saved_models      wsi_dataset.py

# %%
from models.feature_model import Feature_extract
import torch
import graphviz
graphviz.set_jupyter_format('png')

model_name = "DenseNet"  
model = Feature_extract(model=model_name,pretrained_output_channel =1)
print(model)
from torchview import draw_graph
import matplotlib.pyplot as plt


model_graph = draw_graph(model, input_size=(1, 1, 256, 256), expand_nested=True)
model_graph.visual_graph

#model_graph.visual_graph.render(format='png')
# Out:
# Feature_extract(
#   (model): KimiaNet(
#     (model): Sequential(
#       (0): Sequential(
#         (conv0): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#         (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu0): ReLU(inplace=True)
#         (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         (denseblock1): _DenseBlock(
#           (denselayer1): _DenseLayer(
#             (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu1): ReLU(inplace=True)
#             (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu2): ReLU(inplace=True)
#             (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
# ...

# %%
# !ls
# Out:
# Checkpoint_p2.py	    LICENSE	      smooth-topk
# create_heatmaps.sh	    lightning_logs    test_information_part_2.py
# create_patches_features.sh  model.gv	      test_information.py
# CustomOptim		    model.gv.png      train_seeded_cross.py
# dataset.py		    models	      train_seeded.py
# eval.py			    netcal_lib	      utils.py
# eval_utils.py		    __pycache__       VOIDCheckpoint_p3.py
# feature_dataset.py	    README.md	      writer.py
# feature_extraction.py	    requirements.txt  wsi_core
# heatmaps.py		    runs	      wsi_dataset.py
# heatmap_utils.py	    saved_models
